# %% [markdown]
# # Module 3 - Explore the Graph
#
# This module has the following objectives:
# 1. Running Cypher queries to better understand the data
# 2. Deduplicating definitions that are very similar
# 3. Use GDS to find useful patterns in the Graph

# %% [markdown]
# Import our usual suspects (and some more...)

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from graphdatascience import GraphDataScience
from neo4j import Query, GraphDatabase, RoutingControl, Result
from openai import OpenAI
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Setup

# %% [markdown]
# Load env variables

# %%
env_file = 'ws.env'

# %%
if os.path.exists(env_file):
    load_dotenv(env_file, override=True)

    # Neo4j
    HOST = os.getenv('NEO4J_URI')
    USERNAME = os.getenv('NEO4J_USERNAME')
    PASSWORD = os.getenv('NEO4J_PASSWORD')
    DATABASE = os.getenv('NEO4J_DATABASE')
else:
    print(f"File {env_file} not found.")

# %% [markdown]
# Setup connection to the database with the [Python Driver](https://neo4j.com/docs/python-manual/5/).

# %%
driver = GraphDatabase.driver(
    HOST,
    auth=(USERNAME, PASSWORD)
)

# %% [markdown]
# In case we want to split large files

# %%
def split_dataframe(df, chunk_size = 50_000):
    chunks = list()
    num_chunks = len(df) // chunk_size + 1
    for i in range(num_chunks):
        chunks.append(df[i*chunk_size:(i+1)*chunk_size])
    return chunks

# %% [markdown]
# Test the connection

# %%
driver.execute_query(
    """
    MATCH (n) RETURN COUNT(n) as Count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    Count
# 0   1419

# %% [markdown]
# ## Explore the graph
#
# Now to the database and observe what is there. Example queries:
#
# - `MATCH (n:Customer) RETURN n LIMIT 25`
#
# - `MATCH (n:Chunk) RETURN n LIMIT 25`
#
# - `MATCH p=()-[r:PART_OF]->() RETURN p LIMIT 25`
#
# We can also run this via the [Neo4j Python Driver](https://neo4j.com/docs/python-manual/5/) wihtin your Notebook. Let's do so below!

# %% [markdown]
# ### How many Customers are there in the graph?

# %%
driver.execute_query(
    """
    MATCH (cust:Customer) 
    RETURN COUNT(cust)
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    COUNT(cust)
# 0           50

# %% [markdown]
# ### What products do customers have?

# %%
customer_product_df = driver.execute_query(
    """
    MATCH (cust:Customer)-[:HAS_PRODUCT]->(prod:Product)
    WITH DISTINCT cust, COLLECT(prod.name) AS products
    RETURN cust.name AS customer_name, SIZE(products) AS num_products, products LIMIT 10
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
customer_product_df
# Out:
#    customer_name  num_products  \
# 0      Lucas Vos             1
# 1     Rik Meijer             1
# 2    Sara Bakker             2
# 3       Jan Smit             3
# 4   Jan De Vries             1
# 5  Henk De Vries             1
# 6        Eva Bos             2
# 7       Jan Smit             3
# 8       Lars Vos             2
# 9      Bram Smit             2
#
#                                             products
# 0                            [SpaarRekening Product]
# 1                     [RaboBusiness Banking Product]
# 2    [DirectRekening Product, SpaarRekening Product]
# 3  [BeleggersRekening Product, Kortlopende Reis P...
# 4                        [BeleggersRekening Product]
# 5                           [DirectRekening Product]
# 6  [RaboBusiness Banking Product, Kortlopende Rei...
# 7  [RaboBusiness Banking Product, BeleggersRekeni...
# 8  [BeleggersRekening Product, Kortlopende Reis P...
# 9  [SpaarRekening Product, BeleggersRekening Prod...

# %% [markdown]
# ### How many products on average?

# %%
customer_product_df["num_products"].describe()
# Out:
# count    10.000000
# mean      1.800000
# std       0.788811
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       3.000000
# Name: num_products, dtype: float64

# %% [markdown]
# ### What are the most common products?

# %%
product_df = driver.execute_query(
    """
    MATCH (cust:Customer)-[:HAS_PRODUCT]->(prod:Product)
    RETURN DISTINCT prod.name AS product_name, COUNT(cust) AS num_customers ORDER BY num_customers DESC
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
product_df
# Out:
#                    product_name  num_customers
# 0      Kortlopende Reis Product             22
# 1         SpaarRekening Product             21
# 2        DirectRekening Product             18
# 3     BeleggersRekening Product             18
# 4  RaboBusiness Banking Product             14

# %% [markdown]
# ### What documents are in the database?

# %%
document_df = driver.execute_query(
    """
    MATCH (prod_type:ProductType)<-[:RELATED_TO]-(doc:Document) 
    RETURN DISTINCT prod_type.name AS product_type, doc.file_name AS document, doc.pages AS num_pages
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
document_df
# Out:
#            product_type                                           document  \
# 0      Kortlopende Reis         Interpolis Short-Term Travel Insurance.pdf
# 1         SpaarRekening                        Rabo SpaarRekening 2020.pdf
# 2  RaboBusiness Banking  Terms & Conditions for Online Business Service...
# 3        DirectRekening    Payment and Online Services Terms Sept 2022.pdf
# 4     BeleggersRekening              Rabo Beleggersrekening Terms 2020.pdf
#
#    num_pages
# 0         22
# 1         14
# 2         29
# 3         80
# 4         25

# %% [markdown]
# ### How many chunks are the documents split into?

# %%
document_chunks_df = driver.execute_query(
    """
    MATCH (doc:Document)<-[:PART_OF]-(chunk:Chunk)
    WITH DISTINCT doc, COLLECT(chunk) AS chunks
    RETURN doc.file_name AS file_name, doc.pages AS pages, SIZE(chunks) AS chunk_count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
document_chunks_df
# Out:
#                                            file_name  pages  chunk_count
# 0         Interpolis Short-Term Travel Insurance.pdf     22           46
# 1                        Rabo SpaarRekening 2020.pdf     14           44
# 2  Terms & Conditions for Online Business Service...     29           88
# 3    Payment and Online Services Terms Sept 2022.pdf     80          354
# 4              Rabo Beleggersrekening Terms 2020.pdf     25           78

# %% [markdown]
# ---

# %% [markdown]
# ## Extracted Definitions
#
# Let's dive into the extracted definitions.
#
# Some definitions are **very similar** to each other or are **occurring in many documents and chunks**. Let's analyse this and see if we can find solutions to deal with these points!

# %%
definitions_df = driver.execute_query(
    """
    MATCH (doc:Document)<-[:PART_OF]-(chunk:Chunk)-[:MENTIONS]->(def:Definition)
    WITH DISTINCT doc, COLLECT(def) AS definitions
    RETURN doc.file_name AS file_name, SIZE(definitions) AS definition_count, [def in definitions | def.term][0] AS definition_example, [def in definitions | def.description][0] AS description_example
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
definitions_df
# Out:
#                                            file_name  definition_count  \
# 0         Interpolis Short-Term Travel Insurance.pdf               451
# 1                        Rabo SpaarRekening 2020.pdf               570
# 2  Terms & Conditions for Online Business Service...               980
# 3    Payment and Online Services Terms Sept 2022.pdf              4523
# 4              Rabo Beleggersrekening Terms 2020.pdf              1050
#
#      definition_example                                description_example
# 0  terms and conditions  The rules and guidelines that may be changed i...
# 1                  rabo                               Savings Account 2020
# 2        online service  Services that allow you to conduct (banking) b...
# 3               payment  Any payment transaction resulting from the pay...
# 4                  rabo                               Savings Account 2020

# %% [markdown]
# ### What definitions are mentioned most frequently within chunks?
#
# Some definitions are mentioned in many chunks. These "supernodes" are often not informative as they do not capture specific information about the particular chunk itself.

# %%
definition_count_df = driver.execute_query(
    """
    MATCH (doc:Document)<-[:PART_OF]-(chunk:Chunk)-[:MENTIONS]->(def:Definition)
    WITH DISTINCT def, COUNT(DISTINCT chunk) AS chunk_count, COUNT(DISTINCT doc) AS document_count
    RETURN def.term AS definition, def.description AS description, chunk_count, document_count ORDER BY chunk_count DESC LIMIT 25
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
)

# %%
definition_count_df
# Out:
#                       definition  \
# 0                            you
# 1                             we
# 2                        account
# 3                            app
# 4                        payment
# 5                    for example
# 6                         credit
# 7                           rabo
# 8                 online service
# 9                      agreement
# 10               online services
# 11          terms and conditions
# 12                          card
# 13                      security
# 14                         costs
# 15                        person
# 16                      transfer
# 17                      rabobank
# 18                      interest
# 19                online banking
# 20           rabo online banking
# 21                 payment order
# 22                account holder
# 23                         event
# 24  general terms and conditions
#
#                                           description  chunk_count  \
# 0   the account holder, and/or all account holders...          524
# 1                      The Coöperatieve Rabobank U.A.          483
# 2               The payment account you hold with us.          280
# 3   A software application that you must check if ...          275
# 4   Any payment transaction resulting from the pay...          251
# 5   shall be construed as for example without limi...          232
# 6   Includes a construction deposit and conditions...          220
# 7                                Savings Account 2020          205
# 8   Services that allow you to conduct (banking) b...          174
# 9   the agreement concluded between you and us in ...          142
# 10  Services that allow you to manage your (bankin...          135
# 11  The rules and guidelines that may be changed i...          124
# 12      The debit card, credit card, or digital card.          118
# 13  A security can be a mortgage right, a pledge, ...          103
# 14                  Information about costs involved.           99
# 15  If the insured becomes a solo traveler as a re...           95
# 16  We can transfer the claims on you, the rights ...           94
# 17  Rabobank is, among other things, a provider of...           90
# 18  We may pay and/or charge interest on (a part o...           85
# 19              The old name for Rabo Online Banking.           85
# 20  An online service that allows you to bank onli...           83
# 21  Any order given for a payment to be charged to...           77
# 22  the natural person or persons, and/or the lega...           66
# 23        When is this covered? What do we reimburse?           66
# 24  all general terms and conditions applicable to...           62
#
#     document_count
# 0                5
# 1                5
# 2                4
# 3                5
# 4                5
# 5                5
# 6                3
# 7                4
# 8                3
# 9                5
# 10               2
# 11               5
# 12               4
# 13               4
# 14               5
# 15               5
# 16               4
# 17               4
# 18               4
# 19               3
# 20               3
# 21               1
# 22               3
# 23               5
# 24               5

# %% [markdown]
# ## Deduplicate definitions
#
# As you can see, there are many similar/duplicate definitions that we would ideally merge together. That's what we'll try in this section!

# %% [markdown]
# Similar definitions based on [Levenshtein](https://neo4j.com/labs/apoc/4.1/overview/apoc.text/apoc.text.distance/) distance:

# %%
levenshtein_definitions_df = driver.execute_query(
    """
    MATCH (a:Definition), (b:Definition)
    WHERE elementId(a) < elementId(b) AND apoc.text.distance(toLower(a.term), toLower(b.term)) < 3
    RETURN a.term, b.term
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
)

# %%
levenshtein_definitions_df.head(25)
# Out:
#                    a.term                  b.term
# 0          online service        online service/s
# 1                     app                     afm
# 2                  device                 devices
# 3         online services          online service
# 4         online services        online service/s
# 5       security resource      security resources
# 6      product agreements       product agreement
# 7              clause 4.3              clause 8.2
# 8          authorisations           authorization
# 9              rabo alert             rabo alerts
# 10                  event                   agent
# 11                 person                a person
# 12                  agent                   amend
# 13                    bkr                     bic
# 14         security codes           security code
# 15                    pin                    idin
# 16                    pin                     bic
# 17                    pin                    spin
# 18                    pin                     pan
# 19  suspension of payment  suspension of payments
# 20      combined balances        combined balance
# 21         account holder         account holders
# 22                 i-code                  s-code
# 23            06-payments              06-payment
# 24       instant payments         instant payment

# %% [markdown]
# ### Use embeddings
#
# Levenshtein distance is not always ideal, as sometimes completely different terms have small edit distance.
#
# Let's see if embeddings do a better job!

# %%
schema_result_df  = driver.execute_query(
    'SHOW INDEXES',
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
schema_result_df.head()
# Out:
#    id                   name   state  populationPercent    type    entityType  \
# 0   6       chunk-embeddings  ONLINE              100.0  VECTOR          NODE
# 1   7  definition-embeddings  ONLINE              100.0  VECTOR          NODE
# 2   0         index_343aff4e  ONLINE              100.0  LOOKUP          NODE
# 3   1         index_f7700477  ONLINE              100.0  LOOKUP  RELATIONSHIP
# 4   2           unique_chunk  ONLINE              100.0   RANGE          NODE
#
#   labelsOrTypes   properties     indexProvider owningConstraint  \
# 0       [Chunk]  [embedding]        vector-2.0             None
# 1  [Definition]  [embedding]        vector-2.0             None
# 2          None         None  token-lookup-1.0             None
# 3          None         None  token-lookup-1.0             None
# 4       [Chunk]         [id]         range-1.0     unique_chunk
#
#                               lastRead  readCount
# 0  2025-05-16T07:14:50.971000000+00:00          1
# 1  2025-05-16T07:14:51.735000000+00:00          1
# 2  2025-05-15T09:54:11.633000000+00:00       6929
# 3  2025-05-15T06:38:36.692000000+00:00        120
# 4  2025-05-16T07:14:50.481000000+00:00       2461

# %% [markdown]
# Return similar definitions based on embeddings distance:

# %%
similar_definitions_df = driver.execute_query(
    """
    MATCH (n:Definition)
    CALL db.index.vector.queryNodes('definition-embeddings', 10, n.embedding)
    YIELD node AS similar, score
    WHERE elementId(n) < elementId(similar)
    
    //Make sure that the definitions are from the same document
    MATCH (n)<-[:MENTIONS]-(chunk:Chunk)-[:PART_OF]->(source_doc:Document)
    MATCH (similar)<-[:MENTIONS]-(chunk:Chunk)-[:PART_OF]->(target_doc:Document)
    RETURN DISTINCT n.term AS source, similar.term AS target, apoc.coll.sort(COLLECT(source_doc.file_name)) AS source_files, apoc.coll.sort(COLLECT(target_doc.file_name)) AS target_files, score
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
similar_definitions_df
# Out:
#                                                 source  \
# 0                                    outside of europe
# 1                                    outside of europe
# 2                                            worldwide
# 3                                            worldwide
# 4                                 amount of the damage
# ..                                                 ...
# 754            european money markets institute (emmi)
# 755  general terms and conditions 2020, rabo invest...
# 756     security established for the securities credit
# 757  right to use the investor account or the secur...
# 758                     event, change, or circumstance
#
#                                                 target  \
# 0                                               europe
# 1                                            worldwide
# 2                                        world payment
# 3                                               europe
# 4                               maximum amounts we pay
# ..                                                 ...
# 754                                             europe
# 755                       general terms and conditions
# 756  right to use the investor account or the secur...
# 757  account holder of the investor account or the ...
# 758                                              event
#
#                                           source_files  \
# 0    [Interpolis Short-Term Travel Insurance.pdf, P...
# 1         [Interpolis Short-Term Travel Insurance.pdf]
# 2    [Payment and Online Services Terms Sept 2022.pdf]
# 3         [Interpolis Short-Term Travel Insurance.pdf]
# 4         [Interpolis Short-Term Travel Insurance.pdf]
# ..                                                 ...
# 754            [Rabo Beleggersrekening Terms 2020.pdf]
# 755  [Rabo Beleggersrekening Terms 2020.pdf, Rabo B...
# 756            [Rabo Beleggersrekening Terms 2020.pdf]
# 757            [Rabo Beleggersrekening Terms 2020.pdf]
# 758            [Rabo Beleggersrekening Terms 2020.pdf]
#
#                                           target_files     score
# 0    [Interpolis Short-Term Travel Insurance.pdf, P...  0.943314
# 1         [Interpolis Short-Term Travel Insurance.pdf]  0.910599
# 2    [Payment and Online Services Terms Sept 2022.pdf]  0.913681
# 3         [Interpolis Short-Term Travel Insurance.pdf]  0.912994
# 4         [Interpolis Short-Term Travel Insurance.pdf]  0.907486
# ..                                                 ...       ...
# 754            [Rabo Beleggersrekening Terms 2020.pdf]  0.894608
# 755  [Rabo Beleggersrekening Terms 2020.pdf, Rabo B...  0.919220
# 756            [Rabo Beleggersrekening Terms 2020.pdf]  0.927399
# 757            [Rabo Beleggersrekening Terms 2020.pdf]  0.930725
# 758            [Rabo Beleggersrekening Terms 2020.pdf]  0.924530
#
# [759 rows x 5 columns]

# %%
similar_definitions_df.loc[(similar_definitions_df["score"] > 0.97) & (similar_definitions_df["source_files"] == similar_definitions_df["target_files"])].head(10)
# Out:
#                   source                    target  \
# 33   rabo online banking     rabo internet banking
# 34   rabo online banking          rabo banking app
# 41        online service          online service/s
# 95                device                   devices
# 114      online services            online service
# 115      online services  online services/features
# 124    security resource        security resources
# 134   product agreements         product agreement
# 150           rabo alert               rabo alerts
# 195             rabo app          rabo banking app
#
#                                           source_files  \
# 33   [Payment and Online Services Terms Sept 2022.p...
# 34   [Payment and Online Services Terms Sept 2022.p...
# 41   [Terms & Conditions for Online Business Servic...
# 95   [Payment and Online Services Terms Sept 2022.p...
# 114  [Payment and Online Services Terms Sept 2022.p...
# 115  [Terms & Conditions for Online Business Servic...
# 124  [Terms & Conditions for Online Business Servic...
# 134  [Terms & Conditions for Online Business Servic...
# 150  [Terms & Conditions for Online Business Servic...
# 195  [Payment and Online Services Terms Sept 2022.p...
#
#                                           target_files     score
# 33   [Payment and Online Services Terms Sept 2022.p...  0.985077
# 34   [Payment and Online Services Terms Sept 2022.p...  0.972733
# 41   [Terms & Conditions for Online Business Servic...  0.973633
# 95   [Payment and Online Services Terms Sept 2022.p...  0.973557
# 114  [Payment and Online Services Terms Sept 2022.p...  0.983871
# 115  [Terms & Conditions for Online Business Servic...  0.974045
# 124  [Terms & Conditions for Online Business Servic...  0.983459
# 134  [Terms & Conditions for Online Business Servic...  0.982819
# 150  [Terms & Conditions for Online Business Servic...  0.984467
# 195  [Payment and Online Services Terms Sept 2022.p...  0.972900

# %%
similar_terms = similar_definitions_df.loc[(similar_definitions_df["score"] > 0.97) & (similar_definitions_df["source_files"] == similar_definitions_df["target_files"])]
len(similar_terms)
# Out:
# 34

# %% [markdown]
# Number of relations between `Chunk` and `Definition` before deduplicating defintions

# %%
driver.execute_query(
    """
        MATCH p=()-[r:MENTIONS]->() RETURN COUNT(r) as count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    count
# 0   7574

# %% [markdown]
# Number of `Definitions` before deduplicating defintions

# %%
driver.execute_query(
    """
        MATCH (n:Definition) RETURN COUNT(n) as count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    count
# 0    656

# %% [markdown]
# **Merge nodes with similar embeddings**

# %%
for _, row in similar_terms.iterrows():
    driver.execute_query(
        """
        MATCH (a:Definition {term: $source}), (b:Definition {term: $target})
        CALL apoc.refactor.mergeNodes([a, b], {
            properties: "overwrite",
            mergeRels: true
        })
        YIELD node
        RETURN node
        """,
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
        result_transformer_= lambda r: r.to_df(),
        source=row['source'],
        target=row['target']
    )

# %% [markdown]
# Number of relations between `Chunk` and `Definition` after deduplicating defintions

# %%
driver.execute_query(
    """
        MATCH p=()-[r:MENTIONS]->() RETURN COUNT(r) as count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    count
# 0   7425

# %% [markdown]
# Number of `Definitions` after deduplicating defintions

# %%
driver.execute_query(
    """
        MATCH (n:Definition) RETURN COUNT(n) as count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    count
# 0    625

# %% [markdown]
# Look once again at the most occurring definitions

# %%
definition_count_df = driver.execute_query(
    """
    MATCH (doc:Document)<-[:PART_OF]-(chunk:Chunk)-[:MENTIONS]->(def:Definition)
    WITH DISTINCT def, COUNT(DISTINCT chunk) AS chunk_count, COUNT(DISTINCT doc) AS document_count
    RETURN def.term AS definition, def.description AS description, chunk_count, document_count ORDER BY chunk_count DESC LIMIT 25
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
)

# %%
definition_count_df
# Out:
#                       definition  \
# 0                            you
# 1                             we
# 2                        account
# 3                            app
# 4                        payment
# 5                    for example
# 6                         credit
# 7                           rabo
# 8               online service/s
# 9                      agreement
# 10      online services/features
# 11          terms and conditions
# 12                          card
# 13                      security
# 14                         costs
# 15                        person
# 16                      transfer
# 17                rabobank group
# 18                      interest
# 19                online banking
# 20         rabo internet banking
# 21                 payment order
# 22               account holders
# 23                         event
# 24  general terms and conditions
#
#                                           description  chunk_count  \
# 0   the account holder, and/or all account holders...          524
# 1                      The Coöperatieve Rabobank U.A.          483
# 2               The payment account you hold with us.          280
# 3   A software application that you must check if ...          275
# 4   Any payment transaction resulting from the pay...          251
# 5   shall be construed as for example without limi...          232
# 6   Includes a construction deposit and conditions...          220
# 7                                Savings Account 2020          205
# 8   The online services made available by Coöperat...          174
# 9   the agreement concluded between you and us in ...          142
# 10                                          Section 7          135
# 11  The rules and guidelines that may be changed i...          124
# 12      The debit card, credit card, or digital card.          118
# 13  A security can be a mortgage right, a pledge, ...          103
# 14                  Information about costs involved.           99
# 15  If the insured becomes a solo traveler as a re...           95
# 16  We can transfer the claims on you, the rights ...           94
# 17  the economic unit in which we are organization...           90
# 18  We may pay and/or charge interest on (a part o...           85
# 19              The old name for Rabo Online Banking.           85
# 20  The old online environment of Rabobank, which ...           83
# 21  Any order given for a payment to be charged to...           77
# 22      Each account holder may terminate the credit.           66
# 23        When is this covered? What do we reimburse?           66
# 24  all general terms and conditions applicable to...           62
#
#     document_count
# 0                5
# 1                5
# 2                4
# 3                5
# 4                5
# 5                5
# 6                3
# 7                4
# 8                3
# 9                5
# 10               2
# 11               5
# 12               4
# 13               4
# 14               5
# 15               5
# 16               4
# 17               4
# 18               4
# 19               3
# 20               3
# 21               1
# 22               3
# 23               5
# 24               5

# %% [markdown]
# ---

# %% [markdown]
# ### Analyse the Definition graph

# %% [markdown]
# How many definitions did we extract on average from Chunks?

# %%
definitions_per_chunk_df = driver.execute_query(
    """
    MATCH (doc:Document)<-[:PART_OF]-(chunk:Chunk)-[:MENTIONS]->(def:Definition)
    WITH DISTINCT doc, chunk, COUNT(def) AS definition_count
    RETURN doc.file_name AS file_name, AVG(definition_count) AS avg_definitions_per_chunk_count, MIN(definition_count) AS min_definitions_per_chunk_count, MAX(definition_count) AS max_definitions_per_chunk_count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
)

# %%
definitions_per_chunk_df
# Out:
#                                            file_name  \
# 0         Interpolis Short-Term Travel Insurance.pdf
# 1                        Rabo SpaarRekening 2020.pdf
# 2  Terms & Conditions for Online Business Service...
# 3    Payment and Online Services Terms Sept 2022.pdf
# 4              Rabo Beleggersrekening Terms 2020.pdf
#
#    avg_definitions_per_chunk_count  min_definitions_per_chunk_count  \
# 0                         9.804348                                1
# 1                        12.613636                                3
# 2                        10.886364                                2
# 3                        12.685714                                1
# 4                        13.089744                                1
#
#    max_definitions_per_chunk_count
# 0                               15
# 1                               24
# 2                               23
# 3                               32
# 4                               23

# %% [markdown]
# How many shared definitions do documents have?

# %%
doc_name = "Payment and Online Services Terms Sept 2022.pdf"  

shared_definitions_df = driver.execute_query(
    """
    MATCH (doc1:Document {file_name: $doc_name})<-[:PART_OF]-(:Chunk)-[:MENTIONS]->(def:Definition)<-[:MENTIONS]-(:Chunk)-[:PART_OF]->(doc2:Document)
    WHERE doc1 <> doc2
    WITH DISTINCT doc1, doc2, COLLECT(DISTINCT def) AS definitions
    RETURN doc1.file_name AS file_name_1, doc2.file_name AS file_name_2, SIZE(definitions) AS shared_definitions_count ORDER BY shared_definitions_count DESC
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
    doc_name=doc_name
)

# %%
shared_definitions_df
# Out:
#                                        file_name_1  \
# 0  Payment and Online Services Terms Sept 2022.pdf
# 1  Payment and Online Services Terms Sept 2022.pdf
# 2  Payment and Online Services Terms Sept 2022.pdf
# 3  Payment and Online Services Terms Sept 2022.pdf
#
#                                          file_name_2  shared_definitions_count
# 0              Rabo Beleggersrekening Terms 2020.pdf                       104
# 1                        Rabo SpaarRekening 2020.pdf                        95
# 2  Terms & Conditions for Online Business Service...                        71
# 3         Interpolis Short-Term Travel Insurance.pdf                        25

# %% [markdown]
# ### Chunk Similarity
#
# Definitions can be informative about the content of chunks and can for example be used to see which chunks are **similar**
#
# We can define the similarity of chunks based on **overlapping definitions**.

# %% [markdown]
# First, we start by setting the degree property on `Definition` nodes. Definitions occurring in many chunks are less informative, so we can use this property to filter those out!

# %%
# Set property
driver.execute_query(
    """
    MATCH (chunk:Chunk)-[:MENTIONS]->(def:Definition)
    WITH DISTINCT def, COUNT(chunk) AS chunk_count
    SET def.degree = chunk_count
    RETURN COUNT(*) AS rows_processed
    """,
    database_=DATABASE,
    routing_=RoutingControl.WRITE,
    result_transformer_= lambda r: r.to_df()
)
# Out:
#    rows_processed
# 0             570

# %% [markdown]
# Can we find similar chunks?

# %%
threshold = 30  # Used to filter out frequently occurring definitions

similar_chunks_df = driver.execute_query(
    """
    MATCH (chunk_1:Chunk)-[:MENTIONS]->(def:Definition)<-[:MENTIONS]-(chunk_2:Chunk)
    WHERE chunk_1 > chunk_2 AND def.degree <= $threshold
    WITH DISTINCT chunk_1, chunk_2, COLLECT(DISTINCT def.term) AS definitions, COUNT(DISTINCT def) AS definition_count
    WHERE definition_count > 1
    RETURN chunk_1.id AS chunk_1_id ,chunk_1.chunk_eng AS chunk_1, chunk_2.id AS chunk_2_id, chunk_2.chunk_eng AS chunk_2, definitions, definition_count ORDER BY definition_count DESC

    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df(),
    threshold=threshold
)

# %%
len(similar_chunks_df)
# Out:
# 2197

# %%
similar_chunks_df
# Out:
#       chunk_1_id                                            chunk_1  \
# 0            473  f The monthly amounts are paid on time and the...
# 1            472  the amount you have to pay. The law states tha...
# 2            472  the amount you have to pay. The law states tha...
# 3            474  Chapter 7 Credit on the Account and Credit on ...
# 4            474  Chapter 7 Credit on the Account and Credit on ...
# ...          ...                                                ...
# 2192         529  and Rabo Scanner.  \nRates and Limits Overview...
# 2193         441  the device. Once you have approved the cash wi...
# 2194         528  Word List Terms of Payment and Online Services...
# 2195         529  and Rabo Scanner.  \nRates and Limits Overview...
# 2196         337  based on the IBAN.  \n6. There may be a maximu...
#
#       chunk_2_id                                            chunk_2  \
# 0            453  Chapter 7 Credit on the account and Credit on ...
# 1            451  We are allowed to debit the account with the o...
# 2            453  Chapter 7 Credit on the account and Credit on ...
# 3            453  Chapter 7 Credit on the account and Credit on ...
# 4            454  the costs of the cheapest payment package we o...
# ...          ...                                                ...
# 2192         318  with the seller that payment is made per parti...
# 2193         319  3. Are you transferring an amount to a foreign...
# 2194         319  3. Are you transferring an amount to a foreign...
# 2195         319  3. Are you transferring an amount to a foreign...
# 2196         320  information about this can be found in the rat...
#
#                                             definitions  definition_count
# 0     [package, payment package, annual cost percent...                 8
# 1     [package, payment package, credit limit, annua...                 7
# 2     [package, payment package, debit interest, pay...                 6
# 3     [package, payment package, credit on current a...                 6
# 4     [package, payment package, debit interest, ann...                 6
# ...                                                 ...               ...
# 2192         [rates and limits overview, exchange rate]                 2
# 2193          [rates and limits overview, digital card]                 2
# 2194          [rates and limits overview, digital card]                 2
# 2195         [rates and limits overview, exchange rate]                 2
# 2196        [rates and limits overview, transfer money]                 2
#
# [2197 rows x 6 columns]

# %% [markdown]
# We can load the overlapping definition count to the database as **new relationship**

# %%
for chunk in split_dataframe(similar_chunks_df):
    records, summary, keys = driver.execute_query(
        """
        UNWIND $rows AS row
        MERGE (p1:Chunk {id:row.chunk_1_id})
        MERGE (p2:Chunk {id:row.chunk_2_id})
        MERGE (p1)-[s:OVERLAPPING_DEFINITIONS]->(p2)
        SET s.overlap = row.definition_count
        RETURN COUNT(*) AS rows_processed
        """,
        database_=DATABASE,
        routing_=RoutingControl.WRITE,
        rows = chunk.to_dict('records')
    )

# %% [markdown]
# Take a minute to explore the `OVERLAPPING_DEFINITIONS` network in the database
#
# - `MATCH p=()-[:OVERLAPPING_DEFINITIONS]->() RETURN p LIMIT 50`
#
# - `MATCH p=()-[r:OVERLAPPING_DEFINITIONS]->() WHERE r.overlap >= 5 RETURN p LIMIT 50`
#
# - `MATCH p=()-[r:OVERLAPPING_DEFINITIONS]->() WHERE r.overlap >= 10 RETURN p LIMIT 50`

# %% [markdown]
# ### Communities
#
# Let's run some Graph Data Science based on Chunks and Definitions. Let's first setup the [Graph Data Science Client](https://neo4j.com/docs/graph-data-science-client/current/).

# %%
gds = GraphDataScience.from_neo4j_driver(driver=driver)
gds.set_database(DATABASE)
gds.version()
# Out:
# '2.13.4'

# %% [markdown]
# Let's investigate the Chunks that are similar in the graph (based on the definitions they share). For that we first need to create a [Graph object](https://neo4j.com/docs/graph-data-science-client/current/graph-object/)

# %%
graph_name = "chunk_similarity_projection"
node_projection = ["Chunk"]
rel_projection = {"OVERLAPPING_DEFINITIONS": {"orientation": 'UNDIRECTED', "properties": "overlap"}, }

# %%
G, res = gds.graph.project(graph_name, node_projection, rel_projection)

# %%
gds.graph.list()
# Out:
#                                   degreeDistribution  \
# 0  {'min': 0, 'max': 48, 'p90': 21, 'p999': 48, '...
#
#                      graphName database databaseLocation memoryUsage  \
# 0  chunk_similarity_projection     rabo            local    2365 KiB
#
#    sizeInBytes  nodeCount  relationshipCount  \
# 0      2422320        610               4394
#
#                                        configuration   density  \
# 0  {'relationshipProjection': {'OVERLAPPING_DEFIN...  0.011828
#
#                           creationTime                     modificationTime  \
# 0  2025-05-16T09:15:39.162481000+02:00  2025-05-16T09:15:39.162481000+02:00
#
#                                               schema  \
# 0  {'graphProperties': {}, 'nodes': {'Chunk': {}}...
#
#                                schemaWithOrientation
# 0  {'graphProperties': {}, 'nodes': {'Chunk': {}}...

# %% [markdown]
# Run the [Leiden Algorithm](https://neo4j.com/docs/graph-data-science/current/algorithms/leiden/) for Community Detection

# %%
gds.leiden.write(
    G,
    writeProperty='leiden_community',
    relationshipWeightProperty='overlap',
    maxLevels=100,
    gamma=3,
    theta=0.0001,
    concurrency = 1,
    randomSeed = 42
)
# Out:
# writeMillis                                                             16
# nodePropertiesWritten                                                  610
# ranLevels                                                                3
# didConverge                                                           True
# nodeCount                                                              610
# communityCount                                                         196
# communityDistribution    {'min': 1, 'p5': 1, 'max': 42, 'p999': 42, 'p9...
# modularity                                                         0.56275
# modularities             [0.5402389224166195, 0.5610218901220714, 0.562...
# postProcessingMillis                                                     0
# preProcessingMillis                                                      1
# computeMillis                                                           45
# configuration            {'writeProperty': 'leiden_community', 'randomS...
# Name: 0, dtype: object

# %%
communities_df = driver.execute_query(
    """
    MATCH (c:Chunk)
    RETURN c.leiden_community AS community, COUNT(*) as member_count
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
communities_df.sort_values(by='member_count', ascending=False).head(10)
# Out:
#      community  member_count
# 68          11            42
# 26          18            31
# 33          34            28
# 176        130            26
# 71         170            25
# 0          108            23
# 129        132            23
# 27          72            22
# 35          83            21
# 28           1            21

# %%
len(communities_df.loc[lambda df: df['member_count'] > 1])
# Out:
# 27

# %% [markdown]
# Check communities based on Chunks with high overlap

# %%
community_check_df = driver.execute_query(
    """
    MATCH (c1:Chunk)-[s:OVERLAPPING_DEFINITIONS]->(c2:Chunk)
    WHERE s.overlap > 5
    RETURN s.overlap AS overlap, c1.chunk_eng AS chunk_1, c1.leiden_community AS community_1, c2.chunk_eng AS chunk_2, c2.leiden_community AS community_2 ORDER BY s.overlap DESC
    """,
    database_=DATABASE,
    routing_=RoutingControl.READ,
    result_transformer_= lambda r: r.to_df()
)

# %%
community_check_df.head(10)
# Out:
#    overlap                                            chunk_1  community_1  \
# 0        8  f The monthly amounts are paid on time and the...           36
# 1        7  the amount you have to pay. The law states tha...           36
# 2        6  the amount you have to pay. The law states tha...           36
# 3        6  Chapter 7 Credit on the Account and Credit on ...           36
# 4        6  Chapter 7 Credit on the Account and Credit on ...           36
# 5        6  Chapter 7 Credit on the Account and Credit on ...           36
# 6        6  Page 18/24\nGeneral Terms and Conditions 2020,...          130
#
#                                              chunk_2  community_2
# 0  Chapter 7 Credit on the account and Credit on ...           36
# 1  We are allowed to debit the account with the o...           36
# 2  Chapter 7 Credit on the account and Credit on ...           36
# 3  Chapter 7 Credit on the account and Credit on ...           36
# 4  the costs of the cheapest payment package we o...           36
# 5  the amount you have to pay. The law states tha...           36
# 6  Page 17/24\nGeneral Terms and Conditions 2020,...          130

# %% [markdown]
# Check some high definition occurrences in the communities

# %%
communities_definitions_df = gds.run_cypher('''
    MATCH (c:Chunk)-[:MENTIONS]->(def:Definition) WHERE (c.leiden_community) IS NOT NULL AND def.degree <= 30
    WITH c.leiden_community AS leiden_community, def.term as definition, count(*) as cnt
    WHERE cnt > 7
    RETURN *
    ORDER BY leiden_community, cnt DESC
''')

# %%
communities_definitions_df.head(15)
# Out:
#     cnt                 definition  leiden_community
# 0    12  credit on current account                 1
# 1    12      credit on credit card                 1
# 2     8                        dnb                 4
# 3    17               5-digit code                11
# 4    15               rabo scanner                11
# 5    10               signing code                11
# 6     9              random reader                11
# 7     9                     s-code                11
# 8     8                       tool                11
# 9    10                      ideal                14
# 10    9               euro payment                14
# 11   14        framework agreement                18
# 12   10                      annex                18
# 13    9                      amend                18
# 14    9              notice period                18

# %% [markdown]
# ## Plot Communities with their Definition count

# %%
df = gds.run_cypher("""
MATCH (c:Chunk)-[:MENTIONS]->(def:Definition) WHERE (c.leiden_community) IS NOT NULL AND def.degree <= 30
WITH c.leiden_community AS leiden_community, def.term as definition, count(*) as cnt
WHERE cnt > 7
RETURN leiden_community, definition, cnt
""")

# %%
pivot_table = df.pivot(index="definition", columns="leiden_community", values="cnt").fillna(0).sort_index()
sns.set_theme(style="whitegrid")
plt.figure(figsize=(15, 10))
sns.heatmap(pivot_table, cmap="Blues", yticklabels=True, linewidths=0.5)
plt.xlabel("Community")
plt.ylabel("Definition")
plt.title("Definition Distribution Heatmap per Community")
plt.tight_layout()
plt.show()

# %%
G.drop()
# Out:
# graphName                                      chunk_similarity_projection
# database                                                              rabo
# databaseLocation                                                     local
# memoryUsage
# sizeInBytes                                                             -1
# nodeCount                                                              610
# relationshipCount                                                     4394
# configuration            {'relationshipProjection': {'OVERLAPPING_DEFIN...
# density                                                           0.011828
# creationTime                           2025-05-16T09:15:39.162481000+02:00
# modificationTime                       2025-05-16T09:15:39.162481000+02:00
# schema                   {'graphProperties': {}, 'nodes': {'Chunk': {}}...
# schemaWithOrientation    {'graphProperties': {}, 'nodes': {'Chunk': {}}...
# Name: 0, dtype: object
